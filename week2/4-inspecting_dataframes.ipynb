# %% [markdown]
# <a href="https://colab.research.google.com/github/polarpolar914/MachineLearning-for-AI/blob/main/week2/4-inspecting_dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inspecting a DataFrame Object
#
# ## About the Data
# In this notebook, we will be working with earthquake data from September 18, 2018 - October 13, 2018 (obtained from the US Geological Survey (USGS) using the [USGS API](https://earthquake.usgs.gov/fdsnws/event/1/))
#
# ## Setup
# We will be working with the `data/earthquakes.csv` file again, so we need to handle our imports and read it in.

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/earthquakes.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/example_data.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/parsed.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/quakes.db

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/tsunamis.csv

# !mkdir data

# !mv *.csv data

# !mv *.db data
# Out:
# --2024-09-18 23:16:22--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/earthquakes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3515656 (3.4M) [text/plain]
# Saving to: ‘earthquakes.csv’
#
# earthquakes.csv     100%[===================>]   3.35M  --.-KB/s    in 0.08s
#
# 2024-09-18 23:16:22 (42.3 MB/s) - ‘earthquakes.csv’ saved [3515656/3515656]
#
# --2024-09-18 23:16:22--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/example_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 397 [text/plain]
# Saving to: ‘example_data.csv’
#
# example_data.csv    100%[===================>]     397  --.-KB/s    in 0s
#
# 2024-09-18 23:16:23 (6.22 MB/s) - ‘example_data.csv’ saved [397/397]
#
# --2024-09-18 23:16:23--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/parsed.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3616212 (3.4M) [text/plain]
# Saving to: ‘parsed.csv’
#
# parsed.csv          100%[===================>]   3.45M  --.-KB/s    in 0.08s
#
# 2024-09-18 23:16:23 (43.3 MB/s) - ‘parsed.csv’ saved [3616212/3616212]
#
# --2024-09-18 23:16:23--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/quakes.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16384 (16K) [application/octet-stream]
# Saving to: ‘quakes.db’
#
# quakes.db           100%[===================>]  16.00K  --.-KB/s    in 0.001s
#
# 2024-09-18 23:16:23 (11.5 MB/s) - ‘quakes.db’ saved [16384/16384]
#
# --2024-09-18 23:16:23--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/tsunamis.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6792 (6.6K) [text/plain]
# Saving to: ‘tsunamis.csv’
#
# tsunamis.csv        100%[===================>]   6.63K  --.-KB/s    in 0s
#
# 2024-09-18 23:16:23 (72.2 MB/s) - ‘tsunamis.csv’ saved [6792/6792]
#
# mkdir: cannot create directory ‘data’: File exists

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data/earthquakes.csv')

# %% [markdown]
# ## Examining dataframes
# ### Is it empty?

# %%
df.empty
# Out:
# False

# %% [markdown]
# ### What are the dimensions?

# %%
df.shape
# Out:
# (9332, 26)

# %% [markdown]
# ### What columns do we have?
# We know there are 26 columns, but what are they? Let's use the `columns` attribute to see:

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %% [markdown]
# ### What does the data look like?
# View rows from the top with `head()`:

# %%
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...     ,nc,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA        0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 26 columns]

# %% [markdown]
# View rows from the bottom with `tail()`. Let's view 2 rows:

# %%
df.tail(2)
# Out:
#      alert  cdi      code                                             detail  \
# 9330   NaN  NaN  38063959  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9331   NaN  NaN  38063935  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#          dmin  felt   gap           ids   mag magType  ...  sources    status  \
# 9330  0.01865   NaN  61.0  ,ci38063959,  1.10      ml  ...     ,ci,  reviewed
# 9331  0.01698   NaN  39.0  ,ci38063935,  0.66      ml  ...     ,ci,  reviewed
#
#                time                          title  tsunami        type  \
# 9330  1537229545350  M 1.1 - 9km NE of Aguanga, CA        0  earthquake
# 9331  1537228864470  M 0.7 - 9km NE of Aguanga, CA        0  earthquake
#
#                                                   types     tz        updated  \
# 9330  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537230211640
# 9331  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537305830770
#
#                                                     url
# 9330  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %% [markdown]
# *Tip: we can modify the display options in order to see more columns:*
#
# ```python
# # check the max columns setting
# >>> pd.get_option('display.max_columns')
# 20
#
# # set the max columns to show when printing the dataframe to 26
# >>> pd.set_option('display.max_columns', 26)
# # OR
# >>> pd.options.display.max_columns = 26
#
# # reset the option
# >>> pd.reset_option('display.max_columns')
#
# # get information on all display settings
# >>> pd.describe_option('display')
# ```
#
# *More information can be found in the documentation [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html).*
#
# ### What data types do we have?

# %%
df.dtypes
# Out:
# alert       object
# cdi        float64
# code        object
# detail      object
# dmin       float64
# felt       float64
# gap        float64
# ids         object
# mag        float64
# magType     object
# mmi        float64
# net         object
# nst        float64
# place       object
# rms        float64
# sig          int64
# sources     object
# status      object
# time         int64
# title       object
# tsunami      int64
# type        object
# types       object
# tz         float64
# updated      int64
# url         object
# dtype: object

# %% [markdown]
# ### Getting extra info and finding nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9332 entries, 0 to 9331
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alert    59 non-null     object
#  1   cdi      329 non-null    float64
#  2   code     9332 non-null   object
#  3   detail   9332 non-null   object
#  4   dmin     6139 non-null   float64
#  5   felt     329 non-null    float64
#  6   gap      6164 non-null   float64
#  7   ids      9332 non-null   object
#  8   mag      9331 non-null   float64
#  9   magType  9331 non-null   object
#  10  mmi      93 non-null     float64
#  11  net      9332 non-null   object
#  12  nst      5364 non-null   float64
#  13  place    9332 non-null   object
#  14  rms      9332 non-null   float64
#  15  sig      9332 non-null   int64
#  16  sources  9332 non-null   object
#  17  status   9332 non-null   object
#  18  time     9332 non-null   int64
#  19  title    9332 non-null   object
#  20  tsunami  9332 non-null   int64
#  21  type     9332 non-null   object
#  22  types    9332 non-null   object
#  23  tz       9331 non-null   float64
#  24  updated  9332 non-null   int64
#  25  url      9332 non-null   object
# dtypes: float64(9), int64(4), object(13)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Describing and Summarizing
# ### Get summary statistics

# %%
df.describe()
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 25%      2.000000     0.020425    1.000000    66.142500     0.720000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 75%      3.300000     0.177250    5.000000   159.000000     1.900000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# min     0.000000     0.000000     0.000000     0.000000  1.537229e+12
# 25%     2.680000     8.000000     0.119675     8.000000  1.537793e+12
# 50%     3.720000    15.000000     0.210000    26.000000  1.538245e+12
# 75%     4.570000    25.000000     0.590000    56.000000  1.538766e+12
# max     9.120000   172.000000     1.910000  2015.000000  1.539475e+12
#
#            tsunami           tz       updated
# count  9332.000000  9331.000000  9.332000e+03
# mean      0.006537  -451.990140  1.538537e+12
# std       0.080589   231.752571  6.564135e+08
# min       0.000000  -720.000000  1.537230e+12
# 25%       0.000000  -540.000000  1.537996e+12
# 50%       0.000000  -480.000000  1.538621e+12
# 75%       0.000000  -480.000000  1.539110e+12
# max       1.000000   720.000000  1.539537e+12

# %% [markdown]
# Specifying the 5<sup>th</sup> and 95<sup>th</sup> percentile:

# %%
df.describe(percentiles=[0.05, 0.95])
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 5%       2.000000     0.005491    1.000000    35.000000    -0.040000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 95%      4.300000     2.678900   40.200000   276.000000     4.400000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# min     0.000000     0.000000     0.000000     0.000000  1.537229e+12
# 5%      0.000000     4.000000     0.030000     0.000000  1.537344e+12
# 50%     3.720000    15.000000     0.210000    26.000000  1.538245e+12
# 95%     6.380000    49.000000     0.960000   298.000000  1.539319e+12
# max     9.120000   172.000000     1.910000  2015.000000  1.539475e+12
#
#            tsunami           tz       updated
# count  9332.000000  9331.000000  9.332000e+03
# mean      0.006537  -451.990140  1.538537e+12
# std       0.080589   231.752571  6.564135e+08
# min       0.000000  -720.000000  1.537230e+12
# 5%        0.000000  -600.000000  1.537387e+12
# 50%       0.000000  -480.000000  1.538621e+12
# 95%       0.000000   -60.000000  1.539400e+12
# max       1.000000   720.000000  1.539537e+12

# %% [markdown]
# Describe specific data types:

# %%
df.describe(include=object)
# Out:
#         alert      code                                             detail  \
# count      59      9332                                               9332
# unique      2      9332                                               9332
# top     green  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# freq       58         1                                                  1
#
#                  ids magType   net                   place sources    status  \
# count           9332    9331  9332                    9332    9332      9332
# unique          9332      10    14                    5433      52         2
# top     ,ci37389218,      ml    ak  10km NE of Aguanga, CA    ,ak,  reviewed
# freq               1    6803  3166                     306    2981      7797
#
#                                  title        type  \
# count                             9332        9332
# unique                            7807           5
# top     M 0.4 - 10km NE of Aguanga, CA  earthquake
# freq                                55        9081
#
#                                types  \
# count                           9332
# unique                            42
# top     ,geoserve,origin,phase-data,
# freq                            5301
#
#                                                       url
# count                                                9332
# unique                                               9332
# top     https://earthquake.usgs.gov/earthquakes/eventp...
# freq                                                    1

# %% [markdown]
# Or describe all of them:

# %%
df.describe(include='all')
# Out:
#         alert         cdi      code  \
# count      59  329.000000      9332
# unique      2         NaN      9332
# top     green         NaN  37389218
# freq       58         NaN         1
# mean      NaN    2.754711       NaN
# std       NaN    1.010637       NaN
# min       NaN    0.000000       NaN
# 25%       NaN    2.000000       NaN
# 50%       NaN    2.700000       NaN
# 75%       NaN    3.300000       NaN
# max       NaN    8.400000       NaN
#
#                                                    detail         dmin  \
# count                                                9332  6139.000000
# unique                                               9332          NaN
# top     https://earthquake.usgs.gov/fdsnws/event/1/que...          NaN
# freq                                                    1          NaN
# mean                                                  NaN     0.544925
# std                                                   NaN     2.214305
# min                                                   NaN     0.000648
# 25%                                                   NaN     0.020425
# 50%                                                   NaN     0.059050
# 75%                                                   NaN     0.177250
# max                                                   NaN    53.737000
#
#               felt          gap           ids          mag magType  ...  \
# count   329.000000  6164.000000          9332  9331.000000    9331  ...
# unique         NaN          NaN          9332          NaN      10  ...
# top            NaN          NaN  ,ci37389218,          NaN      ml  ...
# freq           NaN          NaN             1          NaN    6803  ...
# mean     12.310030   121.506588           NaN     1.497345     NaN  ...
# std      48.954944    72.962363           NaN     1.203347     NaN  ...
# min       0.000000    12.000000           NaN    -1.260000     NaN  ...
# 25%       1.000000    66.142500           NaN     0.720000     NaN  ...
# 50%       2.000000   105.000000           NaN     1.300000     NaN  ...
# 75%       5.000000   159.000000           NaN     1.900000     NaN  ...
# max     580.000000   355.910000           NaN     7.500000     NaN  ...
#
#         sources    status          time                           title  \
# count      9332      9332  9.332000e+03                            9332
# unique       52         2           NaN                            7807
# top        ,ak,  reviewed           NaN  M 0.4 - 10km NE of Aguanga, CA
# freq       2981      7797           NaN                              55
# mean        NaN       NaN  1.538284e+12                             NaN
# std         NaN       NaN  6.080306e+08                             NaN
# min         NaN       NaN  1.537229e+12                             NaN
# 25%         NaN       NaN  1.537793e+12                             NaN
# 50%         NaN       NaN  1.538245e+12                             NaN
# 75%         NaN       NaN  1.538766e+12                             NaN
# max         NaN       NaN  1.539475e+12                             NaN
#
#             tsunami        type                         types           tz  \
# count   9332.000000        9332                          9332  9331.000000
# unique          NaN           5                            42          NaN
# top             NaN  earthquake  ,geoserve,origin,phase-data,          NaN
# freq            NaN        9081                          5301          NaN
# mean       0.006537         NaN                           NaN  -451.990140
# std        0.080589         NaN                           NaN   231.752571
# min        0.000000         NaN                           NaN  -720.000000
# 25%        0.000000         NaN                           NaN  -540.000000
# 50%        0.000000         NaN                           NaN  -480.000000
# 75%        0.000000         NaN                           NaN  -480.000000
# max        1.000000         NaN                           NaN   720.000000
#
#              updated                                                url
# count   9.332000e+03                                               9332
# unique           NaN                                               9332
# top              NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# freq             NaN                                                  1
# mean    1.538537e+12                                                NaN
# std     6.564135e+08                                                NaN
# min     1.537230e+12                                                NaN
# 25%     1.537996e+12                                                NaN
# 50%     1.538621e+12                                                NaN
# 75%     1.539110e+12                                                NaN
# max     1.539537e+12                                                NaN
#
# [11 rows x 26 columns]

# %% [markdown]
# This works on columns also:

# %%
df.felt.describe()
# Out:
# count    329.000000
# mean      12.310030
# std       48.954944
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max      580.000000
# Name: felt, dtype: float64

# %% [markdown]
# There are methods for specific statistics as well. Here is a sampling of them:
#
# | Method | Description | Data types |
# | --- | --- | --- |
# | `count()` | The number of non-null observations | Any |
# | `nunique()` | The number of unique values | Any |
# | `sum()` | The total of the values | Numerical or Boolean |
# | `mean()` | The average of the values | Numerical or Boolean |
# | `median()` | The median of the values | Numerical |
# | `min()` | The minimum of the values | Numerical |
# | `idxmin()` | The index where the minimum values occurs | Numerical |
# | `max()` | The maximum of the values | Numerical |
# | `idxmax()` | The index where the maximum value occurs | Numerical |
# | `abs()` | The absolute values of the data | Numerical |
# | `std()` | The standard deviation | Numerical |
# | `var()` | The variance |  Numerical |
# | `cov()` | The covariance between two `Series`, or a covariance matrix for all column combinations in a `DataFrame` | Numerical |
# | `corr()` | The correlation between two `Series`, or a correlation matrix for all column combinations in a `DataFrame` | Numerical |
# | `quantile()` | Calculates a specific quantile | Numerical |
# | `cumsum()` | The cumulative sum | Numerical or Boolean |
# | `cummin()` | The cumulative minimum | Numerical |
# | `cummax()` | The cumulative maximum | Numerical |
#
# For example, finding the unique values in the `alert` column:

# %%
df.alert.unique()
# Out:
# array([nan, 'green', 'red'], dtype=object)

# %% [markdown]
# We can then use `value_counts()` to see how many of each unique value we have:

# %%
df.alert.value_counts()
# Out:
# alert
# green    58
# red       1
# Name: count, dtype: int64

# %% [markdown]
# Note that `Index` objects also have several methods to help describe and summarize our data:
#
# | Method | Description |
# | --- | --- |
# | `argmax()`/`argmin()` | Find the location of the maximum/minimum value in the index |
# | `equals()` | Compare the index to another `Index` object for equality |
# | `isin()` | Check if the index values are in a list of values and return an array of Booleans |
# | `max()`/`min()` | Find the maximum/minimum value in the index |
# | `nunique()` | Get the number of unique values in the index |
# | `to_series()` | Create a `Series` object from the index |
# | `unique()` | Find the unique values of the index |
# | `value_counts()`| Create a frequency table for the unique values in the index |

# %% [markdown]
# <hr>
# <div>
#     <a href="./3-making_dataframes_from_api_requests.ipynb">
#         <button style="float: left;">&#8592; Previous Notebook</button>
#     </a>
#     <a href="./5-subsetting_data.ipynb">
#         <button style="float: right;">Next Notebook &#8594;</button>
#     </a>
# </div>
# <br>
# <hr>

# %% [markdown]
# # Tasks 4

# %%
# loc를 사용하여 3번째부터 10번째 행 선택
selected_loc = df.loc[3:10, ['mag', 'magType', 'type']]
print(selected_loc)
# iloc를 사용하여 3번째부터 10번째 행 선택
selected_iloc = df.iloc[3:10, df.columns.get_indexer(['mag', 'magType', 'type'])]
print(selected_iloc)
# Arizona를 포함하는 행 필터링
arizona_items = df[df['place'].str.contains('Arizona', case=False, na=False)]
print(arizona_items)
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake
#     mag magType        type
# 3  0.44      ml  earthquake
# 4  2.16      md  earthquake
# 5  2.61      md  earthquake
# 6  1.70      ml  earthquake
# 7  1.13      md  earthquake
# 8  0.92      md  earthquake
# 9  4.70      mb  earthquake
#      alert  cdi      code                                             detail  \
# 1062   NaN  NaN  60300227  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3965   NaN  NaN  60298572  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids   mag magType  ...  sources    status  \
# 1062  0.1666   NaN  163.0  ,uu60300227,  1.23      ml  ...     ,uu,  reviewed
# 3965  0.1577   NaN  211.0  ,uu60298572,  0.94      md  ...     ,uu,  reviewed
#
#                time                                      title  tsunami  \
# 1062  1539133978610  M 1.2 - 7km SSW of Colorado City, Arizona        0
# 3965  1538383710020  M 0.9 - 7km WSW of Colorado City, Arizona        0
#
#             type                         types     tz        updated  \
# 1062  earthquake  ,geoserve,origin,phase-data, -420.0  1539196068710
# 3965  earthquake  ,geoserve,origin,phase-data, -420.0  1538516934720
#
#                                                     url
# 1062  https://earthquake.usgs.gov/earthquakes/eventp...
# 3965  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %% [markdown]
# # Tasks 5

# %%
# 'alert' 열 삭제
df = df.drop(columns=['alert'])

# %%
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag', 'magType',
#        'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
# 'mag' 열을 꺼내고 'mag'이라는 이름으로 변수에 저장
mag = df.pop('mag')

# 'magType' 열을 꺼내고 'magType'이라는 이름으로 변수에 저장
magType = df.pop('magType')

# %%
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mmi', 'net',
#        'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time', 'title',
#        'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
mag
# Out:
# 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 4       2.16
#         ...
# 9327    0.62
# 9328    1.00
# 9329    2.40
# 9330    1.10
# 9331    0.66
# Name: mag, Length: 9332, dtype: float64

# %%
magType
# Out:
# 0       ml
# 1       ml
# 2       ml
# 3       ml
# 4       md
#         ..
# 9327    md
# 9328    ml
# 9329    md
# 9330    ml
# 9331    ml
# Name: magType, Length: 9332, dtype: object

# %%
import pandas as pd

# 'mag'과 'magType' 시리즈를 열로 연결하여 새로운 데이터프레임 생성
new_df = pd.concat([mag, magType], axis=1)
new_df.columns = ['mag', 'magType']  # 열 이름 설정

# %%
new_df
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]
